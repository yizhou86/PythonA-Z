# %%
import pandas as pd

path = r'C:\Users\Admin\Desktop\Python A-Z\Section 6\P4-Section6-Homework-Dataset.csv'
movies = pd.read_csv(path, encoding = 'latin1')

# %%
len(movies)
# Out:
# 608

# %%
movies.head()
# Out:
#   Day of Week                 Director   Genre        Movie Title  \
# 0      Friday                Brad Bird  action       Tomorrowland
# 1      Friday              Scott Waugh  action     Need for Speed
# 2      Friday           Patrick Hughes  action  The Expendables 3
# 3      Friday  Phil Lord, Chris Miller  comedy     21 Jump Street
# 4      Friday          Roland Emmerich  action   White House Down
#
#   Release Date               Studio Adjusted Gross ($mill)  Budget ($mill)  \
# 0   22/05/2015  Buena Vista Studios                  202.1           170.0
# 1   14/03/2014  Buena Vista Studios                  204.2            66.0
# 2   15/08/2014            Lionsgate                  207.1           100.0
# 3   16/03/2012                 Sony                  208.8            42.0
# 4   28/06/2013                 Sony                  209.7           150.0
#
#   Gross ($mill)  IMDb Rating  MovieLens Rating Overseas ($mill)  Overseas%  \
# ...

# %%
movies.columns
# Out:
# Index(['Day of Week', 'Director', 'Genre', 'Movie Title', 'Release Date',
#        'Studio', 'Adjusted Gross ($mill)', 'Budget ($mill)', 'Gross ($mill)',
#        'IMDb Rating', 'MovieLens Rating', 'Overseas ($mill)', 'Overseas%',
#        'Profit ($mill)', 'Profit%', 'Runtime (min)', 'US ($mill)',
#        'Gross % US'],
#       dtype='object')

# %%
movies.columns = ['DayofWeek', 'Director', 'Genre', 'MovieTitle', 'ReleaseDate',
       'Studio', 'AdjustedGrossMil', 'BudgetMil', 'GrossMil',
       'IMDbRating', 'MovieLensRating', 'OverseasMil', 'Overseas%',
       'ProfitMil)', 'Profit%', 'RuntimeMin', 'USMil',
       'Gross%US']

# %%
movies.head()
# Out:
#   DayofWeek                 Director   Genre         MovieTitle ReleaseDate  \
# 0    Friday                Brad Bird  action       Tomorrowland  22/05/2015
# 1    Friday              Scott Waugh  action     Need for Speed  14/03/2014
# 2    Friday           Patrick Hughes  action  The Expendables 3  15/08/2014
# 3    Friday  Phil Lord, Chris Miller  comedy     21 Jump Street  16/03/2012
# 4    Friday          Roland Emmerich  action   White House Down  28/06/2013
#
#                 Studio AdjustedGrossMil  BudgetMil GrossMil  IMDbRating  \
# 0  Buena Vista Studios            202.1      170.0    202.1         6.7
# 1  Buena Vista Studios            204.2       66.0    203.3         6.6
# 2            Lionsgate            207.1      100.0    206.2         6.1
# 3                 Sony            208.8       42.0    201.6         7.2
# 4                 Sony            209.7      150.0    205.4         8.0
#
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DayofWeek         608 non-null    object
#  1   Director          608 non-null    object
#  2   Genre             608 non-null    object
#  3   MovieTitle        608 non-null    object
#  4   ReleaseDate       608 non-null    object
#  5   Studio            608 non-null    object
#  6   AdjustedGrossMil  608 non-null    object
#  7   BudgetMil         608 non-null    float64
#  8   GrossMil          608 non-null    object
#  9   IMDbRating        608 non-null    float64
#  10  MovieLensRating   608 non-null    float64
#  11  OverseasMil       608 non-null    object
#  12  Overseas%         608 non-null    float64
#  13  ProfitMil)        608 non-null    object
#  14  Profit%           608 non-null    float64
#  15  RuntimeMin        608 non-null    int64
# ...

# %%
# Mistake!!! Don't set them to category. Otherwise it mess up with filtering

#movies.Genre = movies.Genre.astype('category')
#movies.Studio = movies.Studio.astype('category')

# %%
#movies.info()

# %%
#movies.Genre.cat.categories

# %%
#movies.Studio.cat.categories

# %%
Genre_filter = ['action','comedy','adventure','animation','drama']

movies_1 = movies[movies.Genre.isin(Genre_filter)]

Studio_filter = ['Buena Vista Studios','Sony','Universal','WB','Paramount Pictures','Fox']
movies_filtered = movies_1[movies_1.Studio.isin(Studio_filter)]

movies_filtered.head(10)
# Out:
#    DayofWeek                 Director      Genre        MovieTitle  \
# 0     Friday                Brad Bird     action      Tomorrowland
# 1     Friday              Scott Waugh     action    Need for Speed
# 3     Friday  Phil Lord, Chris Miller     comedy    21 Jump Street
# 4     Friday          Roland Emmerich     action  White House Down
# 5     Friday               David Ayer     action              Fury
# 6   Thursday             Rob Marshall  adventure    Into the Woods
# 7     Friday          Daniel Espinosa     action        Safe House
# 8     Friday               Gary Shore     action    Dracula Untold
# 10    Friday              Eric Brevig  animation         Yogi Bear
# 14    Friday              Ryan Murphy      drama     Eat Pray Love
#
#    ReleaseDate               Studio AdjustedGrossMil  BudgetMil GrossMil  \
# 0   22/05/2015  Buena Vista Studios            202.1      170.0    202.1
# 1   14/03/2014  Buena Vista Studios            204.2       66.0    203.3
# ...

# %%
len(movies_filtered)
# Out:
# 423

# %%
movies_filtered.Genre.unique()
# Out:
# array(['action', 'comedy', 'adventure', 'animation', 'drama'],
#       dtype=object)

# %%
movies_filtered.Studio.unique()
# Out:
# array(['Buena Vista Studios', 'Sony', 'Universal', 'WB',
#        'Paramount Pictures', 'Fox'], dtype=object)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = 18,15

# %%
sns.set(style="darkgrid", palette="muted", color_codes=True)

ax = sns.boxplot(data=movies_filtered, x='Genre',y='Gross%US',orient='v', color='lightgray', showfliers=False,)
plt.setp(ax.artists, alpha=0.5)

sns.stripplot(x='Genre', y='Gross%US', data = movies_filtered, jitter=True,size=6,linewidth=0, hue='Studio', alpha=0.7)

ax.axes.set_title('Domestic Gross % by Genre',fontsize=30)
ax.set_xlabel('Genre',fontsize=20)
ax.set_ylabel('Gross % US',fontsize=20)

# Define where to place the legend
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
